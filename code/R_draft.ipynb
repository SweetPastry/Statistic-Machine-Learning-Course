# %%
# 生成1000个均值为0，标准差为1的正态分布随机数
data <- rnorm(1000, mean = 0, sd = 1)

# 绘制直方图
hist(data, breaks = 30, col = "skyblue", main = "Histogram of Normally Distributed Data", xlab = "Value", ylab = "Frequency")
# Out:
# Plot with title "Histogram of Normally Distributed Data"
